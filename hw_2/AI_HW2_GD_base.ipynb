# %% [markdown]
# # **Домашнее задание 2: Градиентный спуск (base)**
#
# В этом задании две части - теоретическая и практическая. Теорию можно набирать, используя LaTex или просто решать на листочке, сфотографировать и отправить вместе с заполненным ноутбуком в anytask.
#
# Максимальный балл за домашнее задание: min{10, ваш балл}.

# %% [markdown]
# ## Задание 1 (0.5 балла)

# %% [markdown]
# Найдите экстремумы следующих функций (вручную, где возможно) и укажите их тип (максимум, минимум):
#
# a) $f(x) = x^2 - 30x + 1$
#
# b) $g(x) = -x^3 + 5x - 7x^2 + 17$
#
# c) $h(x) = x^2 - 1/x$
#
# d) $j(x) = 1/x^5 + x^{17} + 8$

# %% [markdown]
# <blockquote>
#
# $ f'(x) = 2x - 30 $
#
# $ f'(x) = 0 $
#
# **$ (15; -224)$ - точка  минимума**
#
# </blockquote>
#
#
# <blockquote>
#
# $ g'(x) = -3x^2 + 5 - 14x $
#
# $ g''(x) = -6x - 14 $
#
# $ g'(x) = 0 $ ; $ x = -5 $ ; $ x = 1/3 $
#
# **$ (-5; -58) $ - точка минимума**
#
# **$ (1/3; 482/27) $ - точка максимума**
#
# </blockquote>
#
#
# <blockquote>
#
# $ h'(x) = 2x + 1/x^2 $
#
# $ h'(x) = 0 $ ; $ x = -(1/2)^{1/3} $
#
# $ h''(x) = 2 - 2/x^3 $
#
# **$ (-(1/2)^{1/3}; (1/4)^{1/3} + 2^{1/3}) $ - точка минимума**
#
# **$ (1; 0)  $ - точка перегиба**
#
# </blockquote>
#
#
# <blockquote>
#
# $ j'(x) = -5/x^6  + 17x^{16} $
#
# $ j'(x) = 0 $ ; $ x = -(5/17)^{1/22} $ ; $ x = (5/17)^{1/22} $
#
# Тяжело посчитать аналитически...
#
# </blockquote>

# %% [markdown]
# ## Задание 2 (1 балл)

# %% [markdown]
# Найдите экстремумы этих функций в Python.

# %%
# !pip install sympy --upgrade

# %%
import sympy as sp
import numpy as np

x = sp.Symbol('x', real=True)

# %%
def f(x):
  return x**2 - 30*x + 1

df_x  = sp.diff(f(x), x)
df_x
# Out:
# 2*x - 30

# %%
f(x).subs(x, 15)
# Out:
# -224

# %% [markdown]
# **(-15; -224) - точка минимума для функции f(x)**

# %%
def g(x):
  return -x**3 + 5*x - 7*x**2 + 17

dg_x  = sp.diff(g(x), x)
dg_x
# Out:
# -3*x**2 - 14*x + 5

# %%
sp.solve(dg_x, x)
# Out:
# [-5, 1/3]

# %%
g(x).subs(x, -5)
# Out:
# -58

# %%
g(x).subs(x, 1/3)
# Out:
# 17.8518518518519

# %% [markdown]
# **$ (-5; -58) $ - точка минимума для функции g(x)**
#
# **$ (1/3; 482/27) $ - точка максимума для функции g(x)**

# %%
def h(x):
  return x**2 - 1/x

dh_x = sp.diff(h(x), x)
dh_x
# Out:
# 2*x + x**(-2)

# %%
sp.solve(dh_x, x)
# Out:
# [-2**(2/3)/2]

# %%
h(x).subs(x, -2**(2/3)/2)
# Out:
# 1.88988157484231

# %% [markdown]
# **$ (-2**(2/3)/2; 1.88988157484231) $ - точка минимума для функции h(x)**

# %%
def j(x):
  return 1/x**5 + x**(17) + 8

dj_x = sp.diff(j(x), x)
dj_x
# Out:
# 17*x**16 - 5/x**6

# %%
sp.solve(dj_x, x)
# Out:
# [-17**(21/22)*5**(1/22)/17, 17**(21/22)*5**(1/22)/17]

# %%
j(x).subs(x, -17**(21/22)*5**(1/22)/17)
# Out:
# 6.29091200972848

# %%
j(x).subs(x, 17**(21/22)*5**(1/22)/17)
# Out:
# 9.70908799027152

# %% [markdown]
# **$ (-17^{21/22}* 5 ^{1/22}/17; 6.29091200972848) $ - точка максимума для функции j(x)**
#
# **$ (17^{21/22}* 5 ^{1/22}/17; 9.70908799027152) $ - точка минимума для функции j(x)**

# %% [markdown]
# ## Задание 3 (1 балл)

# %% [markdown]
# Найдите точки перегиба функций из задания 1 (вручную, где возможно).

# %% [markdown]
# Вторые производные посчитаны выше (в задании 1).

# %% [markdown]
# **У f(x) нет точек перегиба. $ f''(x) = 2 $**

# %% [markdown]
# **Для g(x) точка перегиба $ (-7/3; -542/27) $**

# %% [markdown]
# **Для h(x) точка перегиба $ (1; 0) $**

# %% [markdown]
# **Для j(x) считать вручную тяжело и долго. Рациональнее использовать библиотеку sympy.**

# %% [markdown]
# ## Задание 4 (1 балла)

# %% [markdown]
# Найдите точки перегиба этих функций в Python.

# %%
d2f_x  = sp.diff(df_x, x)
d2f_x
# Out:
# 2

# %%
d2g_x  = sp.diff(dg_x, x)
d2g_x
# Out:
# -6*x - 14

# %%
sp.solve(d2g_x, x)
# Out:
# [-7/3]

# %%
g(x).subs(x, -7/3)
# Out:
# -20.0740740740741

# %% [markdown]
# **Для g(x) точка перегиба $ (-7/3; −20.0740740740741) $**

# %%
d2h_x  = sp.diff(dh_x, x)
print(d2h_x)
print(sp.solve(d2h_x, x))
# Out:
# 2 - 2/x**3
# [1]

# %%
h(x).subs(x, 1)
# Out:
# 0

# %% [markdown]
# **Для h(x) точка перегиба $ (1; 0) $**

# %%
d2j_x  = sp.diff(dj_x, x)
print(d2j_x)
print(sp.solve(d2j_x, x, real=True))
# Out:
# 272*x**15 + 30/x**7
# ...

# %% [markdown]
# **У функции j(x) точек перебига нет**

# %% [markdown]
# ### Внимание! Далее все задания необходимо выполнять для ВСЕХ функций из задания 1!
#
# ## Задание 5 (1 балл)

# %% [markdown]
# Постройте графики функций из задания 1 в Python (не забудьте подписать оси и сами графики):
# *   изобразите графики с подписанными осями
# *   отметьте одним цветом локальные экстремумы
# *   отметьте другим цветом точки перегиба
# *   подпишите на оси x значения экстремумов и точек перегиба
#
# P.S. Для того, чтобы отметить точку на графике, вам понадобится функция (plt.scatter), а для того, чтобы подписать её значение на оси (plt.annotate).

# %% [markdown]
# Пример хорошего графика:
#
# ![good_graph.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**2 - 30*x + 1

x_values = [x for x in np.arange(-300, 300, 0.1)]
f_values = [f(x) for x in np.arange(-300, 300, 0.1)]

plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-50, 50])
plt.ylim([-300, 300])
plt.xlabel('x')
plt.ylabel('f(x)')
plt.annotate(f'15', (float(15), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
plt.scatter(float(15), float(-224), label = 'Точка минимума', color='red', s=20)
plt.title('График функции f(x)')
plt.plot(x_values, f_values, label='f(x) = $x^2 - 30x + 1$', color='blue')
plt.legend()
plt.show()

# %%
def g(x):
  return -x**3 + 5*x - 7*x**2 + 17

x_values = [x for x in np.arange(-300, 300, 0.1)]
f_values = [g(x) for x in np.arange(-300, 300, 0.1)]

plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-15, 15])
plt.ylim([-100, 100])
plt.xlabel('x')
plt.ylabel('g(x)')
plt.annotate(f'-5', (float(-5), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
plt.annotate(f'1/3', (float(1/3), float(0)), textcoords="offset points", xytext=(2, -10), ha='center')
plt.annotate(f'-7/3', (float(-7/3), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
plt.scatter(float(-5), float(-58), label = 'Точка локального минимума', color='red', s=20)
plt.scatter(float(1/3), float(482/27), label = 'Точка локального максимума', color='yellow', s=20)
plt.scatter(float(-7/3), float(-542/27), label = 'Точка перегиба', color='green', s=20)
plt.title('График функции g(x)')
plt.plot(x_values, f_values, label='g(x) = $-x^3 + 5x - 7x^2 + 17$', color='blue')
plt.legend()
plt.show()

# %%
def h(x):
  return x**2 - 1/x

x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [h(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [h(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('h(x)')
plt.annotate(f'1', (float(1), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.annotate(f'-2^{(0.33)}/2', (float(-2**(1/3)/2), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.scatter(float(1), float(0), label = 'Точка перегиба', color='red', s=20)
plt.scatter(float(-2**(0.6667)/2), float(1.88988), label = 'Точка локального минимума', color='green', s=20)
plt.title('График функции h(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='h(x) = $ x^2 - 1/x $', color='blue')
plt.legend()
plt.show()

# %%
def j(x):
  return 1/x**5 + x**(17) + 8

x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [j(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [j(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('j(x)')
plt.scatter(float(-17**(21/22) * 5**(1/22)/17), float(6.290912), label = 'Точка максимума', color='red', s=30)
plt.scatter(float(17**(21/22) * 5**(1/22)/17), float(9.709088), label = 'Точка минимума', color='green', s=30)
plt.annotate(f'-0.946', (float(-17**(21/22) * 5**(1/22)/17), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.annotate(f'0.946', (float(17**(21/22) * 5**(1/22)/17), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.title('График функции j(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='j(x) = $1/x^5 + x^{17} + 8$', color='blue')
plt.legend()
plt.show()

# %%
print(17**(21/22) * 5**(1/22)/17)
# Out:
# 0.9458926861215569

# %% [markdown]
# ## Задание 6 (1 балл)

# %% [markdown]
# Модифицируйте функцию, осуществляющую метод градиентного спуска с семинара: добавьте опцию останавливать метод, если абсолютное значение производной функции в точке < некоторого $\delta$ (delta добавьте в аргументы функции).

# %%
def gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, f):
  x = sp.Symbol('x')
  df_x = sp.diff(f(x), x)

  x_curr = x_start
  trace = [x_curr]

  for i in range(num_iterations):
    grad_value = df_x.subs(x, x_curr)
    if abs(grad_value) < delta:
      break

    x_new = x_curr - learning_rate * grad_value
    trace.append(x_new)

    if abs(x_new - x_curr) < epsilon:
      return x_new, trace

    x_curr = x_new

  return x_curr, trace

# %% [markdown]
# ## Задание 7 (1 балл)

# %% [markdown]
# Подберите начальное приближение (сделайте несколько запусков из случайной начальной точки) и шаг градиентного спуска таким образом, чтобы процедура выдавала правильное значение наименьшего локального минимума функций (если он есть):
# - [ ] в качестве результата выведите на экран значение начального приближения ($x_0$), `learning_rate`
# - [ ] нарисуйте график функции и изобразите на нём наименьший из найденных локальных минимумов; на оси $x$ подпишите значение этого минимума. \
# (Постарайтесь сделать реализацию графика в виде функции, чтобы оптимизировать процесс. Потом функция понадобится вам в задании 9, но это не обязательное требование).
# - [ ] если такой точки у функции нет, поясните это текстом при помощи Markdown

# %%
import random

def plot_function_with_min(f, x_min, y_min, x_lim_a, x_lim_b, y_lim_a, y_lim_b):
    x_values = [x for x in np.arange(-300, 300, 0.1)]
    y_values = [f(x) for x in np.arange(-300, 300, 0.1)]

    plt.figure(figsize=(8, 8))
    plt.plot(x_values, y_values, label=f'y(x) = {sp.lambdify(x, f(x))(x)}')
    plt.scatter(x_min, y_min, color='red', label=f'Точка минимума: ({x_min:.2f}; {y_min:.2f})')
    plt.annotate(f'{x_min:.2f}', (float(round(x_min)), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
    plt.axvline(x=0, color='black')
    plt.axhline(y=0, color='black')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim([x_lim_a, x_lim_b])
    plt.ylim([y_lim_a, y_lim_b])
    plt.title(f'График функции')
    plt.legend()
    plt.grid(color='gray', linestyle='--', linewidth=0.7)
    plt.show()


x_start = random.randint(-300, 300)
learning_rate = 0.01
epsilon = 1e-6
delta = 1e-3
num_iterations = 1000

x_min, trace = gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, f)
y_min = f(x_min)

plot_function_with_min(f, x_min, y_min, -20, 40, -400, 300)
print(f"минимум: y = {y_min} при x = {x_min}\nНачальное приближение x0 = {x_start}, learning_rate = {learning_rate}")
# Out:
# минимум: y = -223.999999759680 при x = 14.9995097760645
# Начальное приближение x0 = -294, learning_rate = 0.01

# %%
def g(x):
  return -x**3 + 5*x - 7*x**2 + 17

x_start = random.randint(-300, 300)
learning_rate = 0.0005
epsilon = 1e-6
delta = 1e-3
num_iterations = 1000

x_min, trace = gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, g)
y_min = g(x_min)

plot_function_with_min(g, x_min, y_min, -20, 40, -400, 300)
print(f"минимум: y = {y_min} при x = {x_min}\nНачальное приближение x0 = {x_start}, learning_rate = {learning_rate}")
# Out:
# минимум: y = -57.9999789668377 при x = -5.00162129965310
# Начальное приближение x0 = -137, learning_rate = 0.0005

# %%
#для h(x) шаблон не работает :(

def h(x):
  return x**2 - 1/x


x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [h(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [h(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

x_start = random.randint(-300, 0)
learning_rate = 0.005
epsilon = 1e-6
delta = 1e-3
num_iterations = 1000

x_min, trace = gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, h)
y_min = h(x_min)

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('h(x)')
plt.annotate(f'{x_min:.2f}', (float(x_min), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.title('График функции h(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='h(x) = $ x^2 - 1/x $', color='blue')
plt.scatter(x_min, y_min, color='red', label=f'Точка минимума: ({x_min:.2f}; {y_min:.2f})')
plt.legend()
plt.show()


print(f"минимум: y = {y_min} при x = {x_min}\nНачальное приближение x0 = {x_start}, learning_rate = {learning_rate}")
# Out:
# минимум: y = 1.88988165718337 при x = -0.793866208934695
# Начальное приближение x0 = -84, learning_rate = 0.005

# %%
def j(x):
  return 1/x**5 + x**(17) + 8

x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [j(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [j(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

x_start = random.randint(0, 2)
learning_rate = 0.005
epsilon = 1e-6
delta = 1e-3
num_iterations = 1000

x_min, trace = gradient_descent(x_start, learning_rate, epsilon, delta, num_iterations, j)
y_min = j(x_min)

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('j(x)')
plt.scatter(float(round(x_min, 2)), float(round(y_min, 2)), label = 'Точка минимума', color='red', s=30)
plt.annotate(f'{x_min:.2f}', (float(x_min), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.title('График функции j(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='j(x) = $1/x^5 + x^{17} + 8$', color='blue')
plt.legend()
plt.show()

print(f"минимум: y = {y_min} при x = {x_min}\nНачальное приближение x0 = {x_start}, learning_rate = {learning_rate}")
# Out:
# минимум: y = 9.70908799047940 при x = 0.945891085926120
# Начальное приближение x0 = 1, learning_rate = 0.005

# %% [markdown]
# ## Задание 8 (1.5 балла)

# %% [markdown]
# Реализуйте [метод Ньютона](https://en.wikipedia.org/wiki/Newton%27s_method_in_optimization) (метод второго порядка) для поиска минимума функции.
#
# Про метод ещё можно почитать [здесь](https://math.semestr.ru/optim/minimum.php).

# %%
def newton_method(f, df1, df2, x0, epsilon=1e-6, iter=10000):

    x = x0

    for _ in range(iter):
        grad = df1(x)
        hess = df2(x)

        if abs(grad) < epsilon:
            break

        x = x - grad / hess

    return x

# %% [markdown]
# ## Задание 9 (0.5 балла)

# %% [markdown]
# Примените метод Ньютона для поиска минимума указанных функций (в ответе выведите подходящее значение начальной точки, график с найденным и подписанным значением минимума, как в задании 7).

# %%
# не совсем понимаю, в чем смысл строить графики, если мы можем просто сравнить, полученные методом Ньютона значения, с посчитанными выше значениями

# %%
f = lambda x: x**2 - 30*x + 1
df1 = lambda x: 2*x -30
df2 = lambda x: 2

x_min = newton_method(f, df1, df2, x0=0)
print(f"Минимум: x = {x_min}, f(x) = {f(x_min)}")

x_values = [x for x in np.arange(-300, 300, 0.1)]
f_values = [f(x) for x in np.arange(-300, 300, 0.1)]

plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-50, 50])
plt.ylim([-300, 300])
plt.xlabel('x')
plt.ylabel('f(x)')
plt.annotate(f'15', (float(x_min), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
plt.scatter(float(x_min), float(f(x_min)), label='Точка минимума', color='red', s=20)
plt.title('График функции f(x)')
plt.plot(x_values, f_values, label='f(x) = $x^2 - 30x + 1$', color='blue')
plt.legend()
plt.show()
# Out:
# Минимум: x = 15.0, f(x) = -224.0

# %%
g = lambda x: -x**3 + 5*x - 7*x**2 + 17
dg1 = lambda x: -3*x**2 + 5 - 14*x
dg2 = lambda x: -6*x - 14

x_min = newton_method(g, dg1, dg2, x0= -20)
print(f"Минимум: x = {x_min}, g(x) = {g(x_min)}")

x_values = [x for x in np.arange(-300, 300, 0.1)]
f_values = [g(x) for x in np.arange(-300, 300, 0.1)]

plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-15, 15])
plt.ylim([-100, 100])
plt.xlabel('x')
plt.ylabel('g(x)')
plt.annotate(f'-5', (float(-5), float(0)), textcoords="offset points", xytext=(0, -10), ha='center')
plt.scatter(float(x_min), float(g(x_min)), label = 'Точка локального минимума', color='red', s=20)
plt.title('График функции g(x)')
plt.plot(x_values, f_values, label='g(x) = $-x^3 + 5x - 7x^2 + 17$', color='blue')
plt.legend()
plt.show()
# Out:
# Минимум: x = -5.000000018684873, g(x) = -58.000000000000014

# %%
h = lambda x: x**2 - 1/x
dh1 = lambda x: 2*x + 1/x**2
dh2 = lambda x: 2 - 2/x**3

x_min = newton_method(h, dh1, dh2, x0= -20)
print(f"Минимум: x = {x_min}, h(x) = {h(x_min)}")

x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [h(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [h(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('h(x)')
plt.annotate(f'{round(x_min, 3)}', (float(x_min), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.scatter(float(x_min), float(h(x_min)), label = 'Точка локального минимума', color='green', s=20)
plt.title('График функции h(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='h(x) = $ x^2 - 1/x $', color='blue')
plt.legend()
plt.show()
# Out:
# Минимум: x = -0.793700525967382, h(x) = 1.8898815748423097

# %%
j = lambda x: 1/x**5 + x**(17) + 8
dj1 = lambda x: 17*x**16 - 5/x**6
dj2 = lambda x: 272*x**15 + 30/x**7

x_min = newton_method(h, dj1, dj2, x0=0.1)
print(f"Минимум: x = {x_min}, j(x) = {j(x_min)}")

x1_values = [x for x in np.arange(-100, -0.001, 0.001)]
x2_values = [x for x in np.arange(0.001, 100, 0.001)]
f1_values = [j(x) for x in np.arange(-100, -0.001, 0.001)]
f2_values = [j(x) for x in np.arange(0.001, 100, 0.001)]
plt.figure(figsize=(8,8))

plt.axvline(x=0, c = 'black')
plt.axhline(y=0, c = 'black')
plt.grid(color='gray', linestyle='--', linewidth=0.7)
plt.xlim([-5, 5])
plt.ylim([-20, 20])
plt.xlabel('x')
plt.ylabel('j(x)')
plt.scatter(float(x_min), float(j(x_min)), label = 'Точка минимума', color='green', s=30)
plt.annotate(f'{round(x_min, 3)}', (float(x_min), float(0)), textcoords="offset points", xytext=(0, -15), ha='center')
plt.title('График функции j(x)')
plt.plot(x1_values, f1_values, color='blue')
plt.plot(x2_values, f2_values, label='j(x) = $1/x^5 + x^{17} + 8$', color='blue')
plt.legend()
plt.show()
# Out:
# Минимум: x = 0.9458926861247495, j(x) = 9.709087990271517

# %% [markdown]
# ## Задание 10 (1 балл)

# %% [markdown]
# Сравните скорость работы градиентного спуска и метода Ньютона при одинаковой точности решения $|x_{found}-x_{true}|<10^{-5}$:
# * за сколько итераций каждый метод сходится (в среднем по всем функциям для правильно подобранных значений гиперпараметров)? Какой быстрее?
# * какой метод дает более точный результат при фиксированном числе итераций $N=10$? (для ответа на этот вопрос добавьте в процедуру градиентного спуска возможность останавливаться при достижении некоторого количества итераций $N$)

# %% [markdown]
# ## **Бонусная часть**

# %% [markdown]
# ## Задание 11 (1 балл)

# %% [markdown]
# Реализуйте оптимизацию метода градиентного спуска - Momentum. Необходимые выкладки вы можете подсмотреть [здесь](https://education.yandex.ru/handbook/ml/article/optimizaciya-v-ml).

# %%
def gradient_descent_momentum(x_start, learning_rate, epsilon, delta, num_iterations, f, momentum):
    import sympy as sp

    x = sp.Symbol('x')
    df_x = sp.diff(f(x), x)

    x_curr = x_start
    trace = [x_curr]
    velocity = 0

    for i in range(num_iterations):
        grad_value = df_x.subs(x, x_curr)
        if abs(grad_value) < delta:
            break

        velocity = momentum * velocity - learning_rate * grad_value

        x_new = x_curr + velocity
        trace.append(x_new)

        if abs(x_new - x_curr) < epsilon:
            return x_new, trace

        x_curr = x_new

    return x_curr, trace

# %% [markdown]
# ## Задание 12 (0.5 балла)

# %% [markdown]
# Проверьте, решает ли Momentum GD проблему поиска начального приближения для функций из задания 1?

# %%
# your code here

# %% [markdown]
# ## **Часть Котобонус** 🐈
#
# Ура-ура, с вами снова кот, который может добавить вам баллы!
# - 0.25, если вы угадаете, чей он
# - 0.05 если просто предположите
#
# **Подсказка:** кот одной из наших замечательных ассистенток!
#
#
# [Кайфующий кот](https://ibb.co/12WN7wg)

# %% [markdown]
# # Это кот Сабрины!
